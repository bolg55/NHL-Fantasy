# %%
import pandas as pd
from datetime import date, timedelta
from random import randint
from time import sleep
import os
import numpy as np
import pymysql
from sqlalchemy import create_engine
import joblib
import requests
from bs4 import BeautifulSoup
import pulp

# %% [markdown]
# ## TODO
#
# No todo's right now.

# %%
## Variables
year = 2025

# Get today's date
today = date.today()
season_start_date = '2024-10-04'

# %%
username = "root"
password = "Sp1d3rman"
host = "localhost"
port = "3306"
database = "nhl_optimizer"

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %%
query = f"""
SELECT *
FROM player_data
WHERE Date >='{season_start_date}'
"""

df = pd.read_sql(query,engine)

# %%
# Clean the data
df['Date'] = pd.to_datetime(df['Date'])
df = df.drop_duplicates()

df = df.sort_values(by=['Player','Date'])

# %%
# Compute rolling aggregates

# Define the number of games for the rolling window
span = 15 # adjust as needed
min_periods = 15
halflife = 4

# Group by 'Player' and apply rolling calculations
grouped = df.groupby('Player',as_index=False,group_keys=False)

stats = ['GP','TOI', 'TOI/GP', 'Goals/60',
       'Total Assists/60', 'First Assists/60', 'Second Assists/60',
       'Total Points/60', 'IPP', 'Shots/60', 'SH%', 'ixG/60', 'iCF/60',
       'iFF/60', 'iSCF/60', 'iHDCF/60', 'Rush Attempts/60',
       'Rebounds Created/60', 'PIM/60', 'Total Penalties/60', 'Minor/60',
       'Major/60', 'Misconduct/60', 'Penalties Drawn/60', 'Giveaways/60',
       'Takeaways/60', 'Hits/60', 'Hits Taken/60', 'Shots Blocked/60',
       'Faceoffs Won/60', 'Faceoffs Lost/60','Faceoffs %']

for stat in stats:
    df[stat] = grouped[stat].apply(lambda x: x.ewm(halflife=halflife,min_periods=min_periods).mean())
    
latest_stats = df.groupby('Player').tail(1)


final_df = latest_stats[['Player','Team','Position'] + stats].reset_index(drop=True)

# %% [markdown]
# ### Player Point Value Data

# %%
pv_df = pd.read_csv('nhl_players.csv')

# %% [markdown]
# ## Load and Process Models

# %%
# Load the models
loaded_goals_pipeline = joblib.load('goals_model.pkl')
loaded_assists_pipeline = joblib.load('assists_model.pkl')

# Read and process the data
# season_totals = pd.read_csv('season_totals_24.csv',index_col=0)
# season_totals.drop(columns=["Goals/60","Total Assists/60"], inplace=True)

season_totals = final_df.drop(columns=['Goals/60','Total Assists/60'])


# # Predictions
goal_predictions = loaded_goals_pipeline.predict(season_totals)
assist_predictions = loaded_assists_pipeline.predict(season_totals)

# %% [markdown]
# ## Functions

# %%
from datetime import date, timedelta

def fetch_game_data(year: int):
    """
    Fetches the dates of NHL games and teams involved for a given year.
    
    Parameters:
    - year: The year for which you want to fetch game data.

    Returns:
    - DataFrame with dates, visitor, and home teams.
    """
    
    url = f"https://www.hockey-reference.com/leagues/NHL_{year}_games.html"
    dfs = pd.read_html(url)
    df = dfs[0]
    
    # Convert the "Date" column to datetime.date format
    df["Date"] = pd.to_datetime(df["Date"]).dt.date

    # Extract the relevant columns
    game_data = df[["Date", "Visitor", "Home"]]

    return game_data

def filter_dates_for_week(dates, start_date):
    """
    Filters the provided dates for those that fall within the week starting at start_date.
    
    Parameters:
    - dates: List of dates.
    - start_date: The starting date of the week. 

    Returns:
    - A list of dates that fall within the desired week.
    """
    # Convert start_date to a date object if it's a string
    if isinstance(start_date, str):
        start_date = date.fromisoformat(start_date)
    
    # Calculate the end date of the week
    end_date = start_date + timedelta(days=6)

    # Filter the dates
    week_dates = [d for d in dates if start_date <= d <= end_date]
    
    return week_dates

def opponents_for_team_for_week(year, start_date):
    """
    Fetches the opponents each team faces within a specified week.
    
    Parameters:
    - year: The year for which you want to check.
    - start_date: The starting date of the week.

    Returns:
    - A dictionary with teams as keys and lists of opponents as values.
    """
    # Fetch game data for the year
    game_data = fetch_game_data(year)
    
    # Filter the game data for the desired week
    week_dates = filter_dates_for_week(game_data["Date"].tolist(), start_date)
    week_games = game_data[game_data["Date"].isin(week_dates)]
    
    # Prepare opponent information
    visitor_opponents = week_games.set_index("Visitor")["Home"].to_dict()
    home_opponents = week_games.set_index("Home")["Visitor"].to_dict()
    
    opponents = {}
    for team in set(week_games["Visitor"].tolist() + week_games["Home"].tolist()):
        opponents[team] = list(set([visitor_opponents.get(team, "")] + [home_opponents.get(team, "")]))

    return opponents


#-------#

def calculate_weekly_team_multipliers(year, start_date, points_df):
    """
    Calculate the weekly multipliers for teams based on their opponents for a given week.
    """
    
    # Fetch the opponents for each team for the week
    games_week = opponents_for_team_for_week(year, start_date)

    weekly_multipliers = {}
    for team, opponents in games_week.items():
        multipliers = []
        for opponent in opponents:
            multiplier_row = points_df[points_df['Team Name'] == opponent]
            if not multiplier_row.empty:
                multipliers.append(multiplier_row['multiplier'].iloc[0])
            else:
                print(f"Warning: Couldn't find multiplier for opponent {opponent}. Skipping...")

        weekly_multipliers[team] = sum(multipliers) / len(multipliers) if multipliers else 1  # Defaulting to 1 if no games

    return weekly_multipliers


# Now, you can create a new column in your players DataFrame to store the composite multiplier for the week:


def games_count_for_team_for_week(year, start_date):
    """
    Fetches the number of games each team plays within a specified week.
    
    Parameters:
    - year: The year for which you want to check.
    - start_date: The starting date of the week.

    Returns:
    - A dictionary with teams as keys and the number of games they play that week as values.
    """
    
    # Fetch game data for the year
    game_data = fetch_game_data(year)
    
    # Filter the game data for the desired week
    week_dates = filter_dates_for_week(game_data["Date"].tolist(), start_date)
    week_games = game_data[game_data["Date"].isin(week_dates)]
    
    # Count the number of games for each team
    visitor_counts = week_games["Visitor"].value_counts().to_dict()
    home_counts = week_games["Home"].value_counts().to_dict()
    
    total_counts = {}
    for team in set(list(visitor_counts.keys()) + list(home_counts.keys())):
        total_counts[team] = visitor_counts.get(team, 0) + home_counts.get(team, 0)

    return total_counts

# %% [markdown]
# ## Team Name Dict

# %%
# TEAM NAMES
team_abbreviations = {
 'Anaheim Ducks':'ANA',
 'Boston Bruins':'BOS',
 'Buffalo Sabres':'BUF',
 'Calgary Flames':'CGY',
 'Carolina Hurricanes':'CAR',
 'Chicago Blackhawks':'CHI',
 'Colorado Avalanche':'COL',
 'Columbus Blue Jackets':'CBJ',
 'Dallas Stars':'DAL',
 'Detroit Red Wings':'DET',
 'Edmonton Oilers':'EDM',
 'Florida Panthers':'FLA',
 'Los Angeles Kings':'L.A',
 'Minnesota Wild':'MIN',
 'Montreal Canadiens':'MTL',
 'Nashville Predators':'NSH',
 'New Jersey Devils':'N.J',
 'New York Islanders':'NYI',
 'New York Rangers':'NYR',
 'Ottawa Senators':'OTT',
 'Philadelphia Flyers':'PHI',
 'Pittsburgh Penguins':'PIT',
 'San Jose Sharks':'S.J',
 'Seattle Kraken':'SEA',
 'St. Louis Blues':'STL',
 'Tampa Bay Lightning':'T.B',
 'Toronto Maple Leafs':'TOR',
 'Utah Hockey Club':'UTA',
 'Vancouver Canucks':'VAN',
 'Vegas Golden Knights':'VGK',
 'Washington Capitals':'WSH',
 'Winnipeg Jets':'WPG'
}

# %% [markdown]
# ## Injuries

# %%
# Fetch the webpage content
url = "https://www.cbssports.com/nhl/injuries/"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Lists to hold our parsed data
teams = []
injury_dataframes = []

# Iterate over each TableBaseWrapper
for wrapper in soup.find_all('div', class_='TableBaseWrapper'):
    
    # Find team name
    team_name_tag = wrapper.find('span', class_='TeamName')
    if team_name_tag:
        team_name = team_name_tag.get_text(strip=True)
        teams.append(team_name)

        # Find the injury table for the team
        table = wrapper.find('table', class_='TableBase-table')
        if table:
            # Use pandas to read the table
            df = pd.read_html(str(table))[0]
            df['Team'] = team_name  # Add a column for the team name
            injury_dataframes.append(df)

# Concatenate all dataframes
injuries_df = pd.concat(injury_dataframes, ignore_index=True)

#Clean the player name up


def clean_player_name(name):
    # Split the name using spaces to identify potential last names
    parts = name.split()

    # The last word (or the two last words in the case of names like "van Riemsdyk") is likely our surname
    surname = parts[-2] + " " + parts[-1] if len(parts) > 2 and len(parts[-2]) <= 3 else parts[-1]

    # Split by surname and get the second part
    full_name = name.split(surname, 1)[1].strip()

    return full_name if full_name else surname

injuries_df['Player'] = injuries_df['Player'].apply(clean_player_name)

# %% [markdown]
# ## Variables

# %%
## VARIABLES

## Updated to match new scoring rules for Office Pools
fantasy_goals = 2
fantasy_assists = 1
goaltending_win = 2
ot_so_loss = 0
shutout = 2

# all_dates = fetch_game_dates(year)
# week_dates = filter_dates_for_week(all_dates, today)

# %% [markdown]
# #### Win % for SoS Calc

# %%
## GATHER WIN % TO USE FOR SOS CALC

dfs = pd.read_html(f"https://www.hockey-reference.com/leagues/NHL_{year}_standings.html", index_col=0)
east_df = dfs[0].reset_index().rename(columns={'index': 'Team Name'})
west_df = dfs[1].reset_index().rename(columns={'index': 'Team Name'})

east_df = east_df.drop([0, 9], axis=0).reset_index(drop=True)
west_df = west_df.drop([0, 9], axis=0).reset_index(drop=True)
east_df['Team Name'] = east_df['Team Name'].str.replace('*', '', regex=False)
west_df['Team Name'] = west_df['Team Name'].str.replace('*', '', regex=False)


east_df = east_df[['Team Name', 'PTS%']]
west_df = west_df[['Team Name', 'PTS%']]

points_df = pd.concat([east_df, west_df], ignore_index=True)
points_df['PTS%'] = points_df['PTS%'].astype(float)


points_df['Abbreviation'] = points_df['Team Name'].map(team_abbreviations)

# %% [markdown]
# ## Build Reference DataFrame

# %%
# Create dataframe for reference

player_df = pd.DataFrame({
    'Team':season_totals['Team'].values,
    'Position':season_totals['Position'].values,
    'Player':season_totals['Player'].values,
    'Projected Goals/60':goal_predictions,
    'Projected Assists/60':assist_predictions,
    'Projected Goals (TOI)':(season_totals['TOI/GP']/60) * goal_predictions,
    'Projected Assists (TOI)':(season_totals['TOI/GP']/60) * assist_predictions,
})

player_df = player_df.merge(points_df, left_on='Team', right_on='Abbreviation', how='left')

player_df = player_df.round(2).sort_values(by='Projected Goals (TOI)', ascending=False)
player_df['Team'] = player_df['Team Name'].str.split(',').str[0].str.strip()

player_df = player_df[['Team','Abbreviation','Player', 'Position','Projected Goals (TOI)', 'Projected Assists (TOI)']]

player_df = player_df.merge(pv_df[["Team","Player","Position","pv"]], 
                     on=["Team",'Player',"Position"], 
                     how='left')

# 3. Select and rename the desired columns
player_df = player_df.rename(columns={
    'Team_x': 'Old Team',
    'Team_y': 'Team',
})

player_df = player_df[['Team', 'Abbreviation', 'Player', 'Position', 'Projected Goals (TOI)', 'Projected Assists (TOI)']]

# Cleaning the team name (remove asterisks and keep only abbreviation, if needed)
points_df['Team'] = points_df['Team Name']

# Calculating multiplier based on points percentage
points_df['multiplier'] = points_df['PTS%'].apply(lambda x: 0.5 / x if x != 0 else 1.8)

# %%
weekly_multipliers = calculate_weekly_team_multipliers(year, today, points_df)
games_this_week = games_count_for_team_for_week(year, today)


# Map this to your players DataFrame
player_df['weekly_multiplier'] = player_df['Team'].map(weekly_multipliers)
player_df['games_this_week'] = player_df['Team'].map(games_this_week)
# Out:
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...
# Warning: Couldn't find multiplier for opponent . Skipping...

# %%
player_df['projected_goals'] = player_df['Projected Goals (TOI)'] * player_df['weekly_multiplier'] * player_df['games_this_week']
player_df['projected_assists'] = player_df['Projected Assists (TOI)'] * player_df['weekly_multiplier'] * player_df['games_this_week']

# Factoring in fantasy points value for goals and assists
player_df['proj_fantasy_pts'] = (player_df['projected_goals'] * fantasy_goals) + (player_df['projected_assists'] * fantasy_assists)

# Create simple F or D position
player_df.loc[player_df['Position'] != 'D', 'Position'] = 'F'

# %%
# Now, merge on 'Player'
merged_df = pd.merge(player_df, injuries_df[['Player', 'Injury Status']], 
                     on='Player', 
                     how='left')

# Set a new column to indicate if a player is injured or not
merged_df['Injured'] = ~merged_df['Injury Status'].isnull()

# Set the projected fantasy points to 0 for injured players
merged_df['proj_fantasy_pts'] = np.where(merged_df['Injured'], 0, merged_df['proj_fantasy_pts'])

# %%
projections_df = merged_df[['Team','Injured','Player','Position','games_this_week','proj_fantasy_pts']]

# %% [markdown]
# ## Add Team Goaltending Calcs

# %%
def estimate_team_goaltending_points(weekly_multipliers, games_this_week, win_points, ot_loss_points, shutout_bonus, avg_ot_loss_freq=0.1, avg_shutout_freq=0.05):
    """
    Estimate the team goaltending points for the week using weekly multipliers, 
    number of games this week, and the fantasy points system.

    Returns:
    - A dictionary with team abbreviations as keys and a tuple of projected goaltending points and games_this_week as values.
    """

    goaltending_data = {}

    for team, multiplier in weekly_multipliers.items():
        games = games_this_week.get(team, 0)

        # Estimate wins based on multiplier (inverse relation)
        projected_wins = games / multiplier
        projected_ot_losses = games * avg_ot_loss_freq  # You can adjust or use team-specific data
        projected_shutouts = games * avg_shutout_freq   # You can adjust or use team-specific data

        total_points = (projected_wins * win_points) + (projected_ot_losses * ot_loss_points) + (projected_shutouts * shutout_bonus)
        
        goaltending_data[team] = (total_points,games)

    return goaltending_data

# Using the function
goaltending_data = estimate_team_goaltending_points(weekly_multipliers, games_this_week, goaltending_win, ot_so_loss, shutout)

# Convert to DataFrame
df = pd.DataFrame(goaltending_data.values(), index=goaltending_data.keys(), columns=['proj_fantasy_pts', 'games_this_week'])

# Reset index to have the teams as a separate column
df = df.reset_index().rename(columns={"index": "Team"})

# Add the position
df["Position"] = "G" 
df['Injured'] = False
df['Player'] = df['Team']


goalie_df = df[['Team','Injured','Player','Position','games_this_week','proj_fantasy_pts']]

# %% [markdown]
# ## Final DataFrame Ready for Optimization

# %%
# Add goalie df to player df
final_df = pd.concat([projections_df, goalie_df], ignore_index=True).round(2)

## Add player values
final_df = pd.merge(final_df, pv_df[["Team","Player","Position","pv"]], 
                     on=['Team',"Position",'Player'], 
                     how='left')

final_df.loc[final_df['Position'] =='G','pv'] = 0

final_df = final_df.sort_values(by=["pv","proj_fantasy_pts"], ascending=False)

# %% [markdown]
# ## Optimize Lineup

# %%
## OPTIMIZATION RULES

"""
- 6 Forwards MUST be selected
- 4 Defense MUST be selected
- 2 team Goaltenders MUST be selected
- A team CANNOT go over the salary cap (MAX_COST)
- At most 5 players from a single team may be represented in the lineup
"""

MAX_COST = 63.00
MIN_COST = MAX_COST * 0.99
NUM_FORWARDS = 6
NUM_DEFENSEMEN = 4 
NUM_GOALIES = 2
MAX_PLAYERS_PER_TEAM = 5

final_df = final_df.dropna(subset=['proj_fantasy_pts', 'pv'])

def select_best_team(df, max_cost, min_cost, num_forwards, num_defensemen, num_goalies, max_players_per_team):
    # Create a linear programming problem
    prob = pulp.LpProblem("FantasyHockeyTeam", pulp.LpMaximize)

    # Create decision variables (binary: 1 if player i is selected, 0 otherwise)
    player_vars = pulp.LpVariable.dicts("player", df.index, cat="Binary")

    # Objective: Maximize total fantasy points
    prob += pulp.lpSum(df['proj_fantasy_pts'][i] * player_vars[i] for i in df.index), "Total Fantasy Points"

    # Salary cap constraints
    prob += pulp.lpSum(df['pv'][i] * player_vars[i] for i in df.index) <= max_cost, "Total Salary Cost"
    prob += pulp.lpSum(df['pv'][i] * player_vars[i] for i in df.index) >= min_cost, "Minimum Salary Cost"

    # Positional constraints
    prob += pulp.lpSum(player_vars[i] for i in df[df['Position'] == 'F'].index) == num_forwards, "Number of Forwards"
    prob += pulp.lpSum(player_vars[i] for i in df[df['Position'] == 'D'].index) == num_defensemen, "Number of Defensemen"
    prob += pulp.lpSum(player_vars[i] for i in df[df['Position'] == 'G'].index) == num_goalies, "Number of Goalies"

    # Limit players per team
    teams = df['Team'].unique()
    for team in teams:
        team_player_indices = df[df['Team'] == team].index
        prob += pulp.lpSum(player_vars[i] for i in team_player_indices) <= max_players_per_team, f"MaxPlayers_{team}"

    # 1) At most 1 defenseman per team
    for team in teams:
        team_defense_indices = df[(df['Team'] == team) & (df['Position'] == 'D')].index
        prob += pulp.lpSum(player_vars[i] for i in team_defense_indices) <= 1, f"Max1D_{team}"

#     # 2) At least one team has >= 2 forwards
#     b_team_has2F = pulp.LpVariable.dicts("team_has_2_forwards", teams, cat="Binary")
#     BIG_M = 6  # Since we choose 6 forwards total, no team can exceed 6
#     for team in teams:
#         team_forward_indices = df[(df['Team'] == team) & (df['Position'] == 'F')].index
#         f_t = pulp.lpSum(player_vars[i] for i in team_forward_indices)
#         prob += f_t <= BIG_M * b_team_has2F[team], f"Fwd_Upp_{team}"
#         prob += f_t >= 3 * b_team_has2F[team], f"Fwd_Low_{team}"

#     # At least one team with b_team_has2F[team] = 1
#     prob += pulp.lpSum(b_team_has2F[t] for t in teams) >= 1, "AtLeastOneTeamHas2F"

    # Solve the problem
    prob.solve(pulp.PULP_CBC_CMD())

    # Extract selected players
    selected_players = [i for i in df.index if player_vars[i].varValue == 1]
    best_team = df.loc[selected_players]

    return best_team


# Assuming your dataframe is named final_df, and you have defined constants for max_cost, num_forwards, etc.
best_team = select_best_team(final_df, MAX_COST,MIN_COST,NUM_FORWARDS, NUM_DEFENSEMEN, NUM_GOALIES,MAX_PLAYERS_PER_TEAM)


# Calculate total projected points and total cost for the chosen players from best_team
total_projected_points = sum(best_team.proj_fantasy_pts)
total_cost = sum(best_team.pv)

# Displaying the results

# Create a dataframe with the values
cost = pd.DataFrame({'total_proj_pts': [total_projected_points], 'total_cost': [total_cost]})
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/kellen/anaconda3/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/88ae9c3112504c898f680e5e413736be-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/88ae9c3112504c898f680e5e413736be-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 72 COLUMNS
# At line 3947 RHS
# At line 4015 BOUNDS
# At line 4570 ENDATA
# Problem MODEL has 67 rows, 554 columns and 2346 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 50.7899 - 0.00 seconds
# Cgl0004I processed model has 60 rows, 540 columns (540 integer (534 of which binary)) and 1765 elements
# Cutoff increment increased from 1e-05 to 0.00999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.0192857
# Cbc0038I Pass   1: suminf.    0.00619 (2) obj. -50.7726 iterations 9
# Cbc0038I Pass   2: suminf.    0.93164 (2) obj. -47.6225 iterations 6
# Cbc0038I Pass   3: suminf.    0.60553 (2) obj. -47.2338 iterations 3
# Cbc0038I Pass   4: suminf.    0.55930 (2) obj. -25.9717 iterations 31
# Cbc0038I Pass   5: suminf.    0.33351 (2) obj. -25.9051 iterations 4
# Cbc0038I Pass   6: suminf.    0.81283 (2) obj. -25.073 iterations 4
# Cbc0038I Pass   7: suminf.    0.05212 (2) obj. -25.9048 iterations 4
# Cbc0038I Pass   8: suminf.    0.07144 (2) obj. -19.1336 iterations 19
# Cbc0038I Solution found of -19.08
# Cbc0038I Cleaned solution of -19.08
# Cbc0038I Before mini branch and bound, 507 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 60 rows 540 columns, reduced to 7 rows 33 columns
# Cbc0038I Mini branch and bound improved solution from -19.08 to -49.42 (0.01 seconds)
# Cbc0038I Round again with cutoff of -49.566
# Cbc0038I Reduced cost fixing fixed 424 variables on major pass 2
# Cbc0038I Pass   9: suminf.    0.00613 (2) obj. -50.788 iterations 5
# Cbc0038I Pass  10: suminf.    0.48000 (2) obj. -50.2972 iterations 3
# Cbc0038I Pass  11: suminf.    0.36252 (2) obj. -50.3101 iterations 3
# Cbc0038I Pass  12: suminf.    0.64885 (4) obj. -49.566 iterations 12
# Cbc0038I Solution found of -49.79
# Cbc0038I Cleaned solution of -49.79
# Cbc0038I Before mini branch and bound, 529 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 60 rows 540 columns, reduced to 4 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -49.998
# Cbc0038I Reduced cost fixing fixed 477 variables on major pass 3
# Cbc0038I Pass  13: suminf.    0.00613 (2) obj. -50.788 iterations 0
# Cbc0038I Pass  14: suminf.    0.48000 (2) obj. -50.2972 iterations 3
# Cbc0038I Pass  15: suminf.    0.36252 (2) obj. -50.3101 iterations 2
# Cbc0038I Pass  16: suminf.    1.34813 (4) obj. -49.998 iterations 8
# Cbc0038I Pass  17: suminf.    0.90979 (4) obj. -49.998 iterations 4
# Cbc0038I Pass  18: suminf.    0.28244 (2) obj. -50.6539 iterations 4
# Cbc0038I Pass  19: suminf.    0.26689 (3) obj. -49.998 iterations 11
# Cbc0038I Pass  20: suminf.    0.26689 (3) obj. -49.998 iterations 2
# Cbc0038I Pass  21: suminf.    0.90079 (3) obj. -49.998 iterations 9
# Cbc0038I Pass  22: suminf.    0.90079 (3) obj. -49.998 iterations 0
# Cbc0038I Pass  23: suminf.    0.91333 (3) obj. -49.998 iterations 4
# Cbc0038I Pass  24: suminf.    0.91333 (3) obj. -49.998 iterations 0
# Cbc0038I Pass  25: suminf.    0.95127 (2) obj. -50.1535 iterations 4
# Cbc0038I Pass  26: suminf.    0.95127 (2) obj. -50.1535 iterations 0
# Cbc0038I Pass  27: suminf.    0.92910 (3) obj. -49.998 iterations 3
# Cbc0038I Pass  28: suminf.    0.96431 (4) obj. -49.998 iterations 9
# Cbc0038I Pass  29: suminf.    0.69846 (3) obj. -49.998 iterations 4
# Cbc0038I Pass  30: suminf.    0.88758 (2) obj. -50.0695 iterations 6
# Cbc0038I Pass  31: suminf.    0.76742 (3) obj. -49.998 iterations 4
# Cbc0038I Pass  32: suminf.    0.92907 (4) obj. -49.998 iterations 10
# Cbc0038I Pass  33: suminf.    0.43365 (3) obj. -49.998 iterations 4
# Cbc0038I Pass  34: suminf.    0.81434 (3) obj. -49.998 iterations 5
# Cbc0038I Pass  35: suminf.    0.57643 (2) obj. -50.1642 iterations 1
# Cbc0038I Pass  36: suminf.    1.00000 (3) obj. -49.998 iterations 3
# Cbc0038I Pass  37: suminf.    0.77051 (3) obj. -49.998 iterations 6
# Cbc0038I Pass  38: suminf.    0.06744 (2) obj. -50.2177 iterations 6
# Cbc0038I Pass  39: suminf.    0.93053 (3) obj. -49.998 iterations 4
# Cbc0038I Pass  40: suminf.    1.28407 (4) obj. -49.998 iterations 10
# Cbc0038I Pass  41: suminf.    0.82432 (2) obj. -49.998 iterations 3
# Cbc0038I Pass  42: suminf.    0.83198 (4) obj. -49.998 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 518 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 60 rows 540 columns, reduced to 8 rows 20 columns
# Cbc0038I Mini branch and bound improved solution from -49.79 to -50.3 (0.02 seconds)
# Cbc0038I Round again with cutoff of -50.454
# Cbc0038I Reduced cost fixing fixed 515 variables on major pass 4
# Cbc0038I Pass  42: suminf.    0.00741 (2) obj. -50.7896 iterations 6
# Cbc0038I Pass  43: suminf.    0.47645 (2) obj. -50.7233 iterations 6
# Cbc0038I Pass  44: suminf.    0.33173 (2) obj. -50.7284 iterations 5
# Cbc0038I Pass  45: suminf.    0.10414 (2) obj. -50.454 iterations 9
# Cbc0038I Solution found of -50.48
# Cbc0038I Cleaned solution of -50.48
# Cbc0038I Before mini branch and bound, 533 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 60 rows 540 columns, reduced to 4 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -50.58
# Cbc0038I Reduced cost fixing fixed 522 variables on major pass 5
# Cbc0038I Pass  46: suminf.    0.00741 (2) obj. -50.7896 iterations 0
# Cbc0038I Pass  47: suminf.    0.47645 (2) obj. -50.7233 iterations 6
# Cbc0038I Pass  48: suminf.    0.33173 (2) obj. -50.7284 iterations 5
# Cbc0038I Pass  49: suminf.    0.51857 (2) obj. -50.7326 iterations 6
# Cbc0038I Pass  50: suminf.    0.16819 (2) obj. -50.6989 iterations 3
# Cbc0038I Pass  51: suminf.    0.55184 (2) obj. -50.6641 iterations 4
# Cbc0038I Pass  52: suminf.    0.42647 (2) obj. -50.6904 iterations 3
# Cbc0038I Pass  53: suminf.    0.15133 (2) obj. -50.6506 iterations 4
# Cbc0038I Pass  54: suminf.    0.06229 (2) obj. -50.6363 iterations 3
# Cbc0038I Pass  55: suminf.    0.74736 (3) obj. -50.58 iterations 9
# Cbc0038I Pass  56: suminf.    0.40309 (4) obj. -50.58 iterations 2
# Cbc0038I Pass  57: suminf.    0.63261 (3) obj. -50.58 iterations 6
# Cbc0038I Pass  58: suminf.    0.16819 (2) obj. -50.6989 iterations 1
# Cbc0038I Pass  59: suminf.    0.55184 (2) obj. -50.6641 iterations 4
# Cbc0038I Pass  60: suminf.    0.42647 (2) obj. -50.6904 iterations 3
# Cbc0038I Pass  61: suminf.    0.74432 (3) obj. -50.58 iterations 2
# Cbc0038I Pass  62: suminf.    0.42647 (2) obj. -50.6904 iterations 2
# Cbc0038I Pass  63: suminf.    0.65551 (4) obj. -50.58 iterations 2
# Cbc0038I Pass  64: suminf.    0.55108 (3) obj. -50.58 iterations 4
# Cbc0038I Pass  65: suminf.    0.18576 (2) obj. -50.6189 iterations 5
# Cbc0038I Pass  66: suminf.    0.18576 (2) obj. -50.6189 iterations 0
# Cbc0038I Pass  67: suminf.    1.00000 (3) obj. -50.58 iterations 10
# Cbc0038I Pass  68: suminf.    0.72399 (3) obj. -50.58 iterations 1
# Cbc0038I Pass  69: suminf.    0.80914 (4) obj. -50.58 iterations 10
# Cbc0038I Pass  70: suminf.    0.78266 (4) obj. -50.58 iterations 3
# Cbc0038I Pass  71: suminf.    0.00741 (2) obj. -50.7896 iterations 6
# Cbc0038I Pass  72: suminf.    0.47645 (2) obj. -50.7233 iterations 6
# Cbc0038I Pass  73: suminf.    0.33173 (2) obj. -50.7284 iterations 5
# Cbc0038I Pass  74: suminf.    0.87715 (4) obj. -50.58 iterations 8
# Cbc0038I Pass  75: suminf.    0.77829 (3) obj. -50.58 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 528 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 60 rows 540 columns, reduced to 7 rows 12 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -50.48 - took 0.03 seconds
# Cbc0012I Integer solution of -50.48 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 60 rows 540 columns, reduced to 4 rows 6 columns
# Cbc0031I 5 added rows had average density of 112.4
# Cbc0013I At root node, 5 cuts changed objective from -50.789904 to -50.692222 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 11.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 6 row cuts average 12.8 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 3 row cuts average 510.3 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -50.48 best solution, best possible -50.692222 (0.04 seconds)
# Cbc0012I Integer solution of -50.58 found by DiveCoefficient after 36 iterations and 2 nodes (0.04 seconds)
# Cbc0001I Search completed - best objective -50.58, took 52 iterations and 4 nodes (0.04 seconds)
# Cbc0032I Strong branching done 18 times (48 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 1, 528 variables fixed on reduced cost
# Cuts at root node changed objective from -50.7899 to -50.6922
# Probing was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 15 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 15 times and created 13 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 15 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# FlowCover was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                50.58000000
# Enumerated nodes:               4
# Total iterations:               52
# Time (CPU seconds):             0.04
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05

# %% [markdown]
# # Lineup

# %%
print(cost)
best_team.sort_values(by='Position')
# Out:
#    total_proj_pts  total_cost
# 0           50.58      62.594
#                     Team  Injured              Player Position  \
# 339       Buffalo Sabres    False       Rasmus Dahlin        D
# 278  Tampa Bay Lightning    False         Erik Cernak        D
# 360   Montreal Canadiens    False   Alexandre Carrier        D
# 301     Utah Hockey Club    False         Olli Maatta        D
# 19   Tampa Bay Lightning    False       Brayden Point        F
# 26    Montreal Canadiens    False       Cole Caufield        F
# 5           Dallas Stars    False     Jason Robertson        F
# 18      Utah Hockey Club    False      Clayton Keller        F
# 76   Tampa Bay Lightning    False       Brandon Hagel        F
# 11          Dallas Stars    False      Wyatt Johnston        F
# 856     Utah Hockey Club    False    Utah Hockey Club        G
# 847   Montreal Canadiens    False  Montreal Canadiens        G
#
#      games_this_week  proj_fantasy_pts      pv
# 339              1.0              2.01  11.000
# 278              2.0              2.81   5.200
# 360              2.0              2.44   3.750
# 301              2.0              3.09   3.000
# 19               2.0              5.62   9.500
# 26               2.0              5.21   7.850
# 5                1.0              5.12   7.750
# 18               2.0              4.20   7.150
# 76               2.0              4.36   6.500
# 11               1.0              4.79   0.894
# 856              2.0              6.05   0.000
# 847              2.0              4.88   0.000

# %% [markdown]
# ## Captains

# %%
# Find the top players by position based on 'proj_fantasy_pts'
top_players = best_team.loc[best_team.groupby('Position')['proj_fantasy_pts'].idxmax()]

top_players
# Out:
#                     Team  Injured            Player Position  games_this_week  \
# 301     Utah Hockey Club    False       Olli Maatta        D              2.0
# 19   Tampa Bay Lightning    False     Brayden Point        F              2.0
# 856     Utah Hockey Club    False  Utah Hockey Club        G              2.0
#
#      proj_fantasy_pts   pv
# 301              3.09  3.0
# 19               5.62  9.5
# 856              6.05  0.0

# %%
data = [{'Team': key, 'Multiplier': value} for key, value in weekly_multipliers.items()]
multipliers = pd.DataFrame(data)
multipliers.sort_values(by="Multiplier").round(2)
# Out:
#                      Team  Multiplier
# 19       Utah Hockey Club        0.68
# 6         San Jose Sharks        0.77
# 26          Boston Bruins        0.79
# 0       Vancouver Canucks        0.79
# 8      New York Islanders        0.81
# 13        Ottawa Senators        0.81
# 3           Anaheim Ducks        0.81
# 23      Detroit Red Wings        0.85
# 10     Montreal Canadiens        0.85
# 24    Toronto Maple Leafs        0.88
# 5        Florida Panthers        0.89
# 11         Seattle Kraken        0.92
# 2        New York Rangers        0.92
# 14   Vegas Golden Knights        0.93
# 25         Minnesota Wild        0.95
# 15  Columbus Blue Jackets        0.96
# 18    Tampa Bay Lightning        0.98
# 20    Washington Capitals        0.98
# 21    Carolina Hurricanes        0.98
# 28      New Jersey Devils        0.98
# 27    Philadelphia Flyers        1.02
# 22      Los Angeles Kings        1.02
# 7      Chicago Blackhawks        1.04
# 4     Pittsburgh Penguins        1.06
# 17    Nashville Predators        1.08
# 12         Calgary Flames        1.12
# 16         Buffalo Sabres        1.23
# 1         St. Louis Blues        1.35
# 9            Dallas Stars        1.52

# %%
games_this_week
# Out:
# {'Vancouver Canucks': 1,
#  'St. Louis Blues': 1,
#  'New York Rangers': 1,
#  'Anaheim Ducks': 1,
#  'Pittsburgh Penguins': 1,
#  'Florida Panthers': 1,
#  'San Jose Sharks': 1,
#  'Chicago Blackhawks': 1,
#  'New York Islanders': 1,
#  'Dallas Stars': 1,
#  'Montreal Canadiens': 2,
#  'Seattle Kraken': 1,
#  'Calgary Flames': 1,
#  'Ottawa Senators': 1,
#  'Vegas Golden Knights': 1,
#  'Columbus Blue Jackets': 1,
#  'Buffalo Sabres': 1,
#  'Nashville Predators': 1,
#  'Tampa Bay Lightning': 2,
#  'Utah Hockey Club': 2,
#  'Washington Capitals': 1,
#  'Carolina Hurricanes': 1,
#  'Los Angeles Kings': 1,
#  'Detroit Red Wings': 1,
#  'Toronto Maple Leafs': 1,
#  'Minnesota Wild': 1,
#  'Boston Bruins': 1,
#  'Philadelphia Flyers': 1,
#  'New Jersey Devils': 1}

# %%
injuries_df
# Out:
#                 Player Position      Updated      Injury  \
# 0          Radko Gudas        D   Thu, Feb 6     Illness
# 1         Brock McGinn       LW  Mon, Jan 27  Lower Body
# 2      Hampus Lindholm        D  Wed, Jan 29  Lower Body
# 3        Tage Thompson        C   Wed, Feb 5  Concussion
# 4       Beck Malenstyn       LW   Wed, Feb 5        Back
# ..                 ...      ...          ...         ...
# 101       Sonny Milano       LW  Tue, Jan 28  Upper Body
# 102  Nicklas Backstrom        C  Mon, Jan 27         Hip
# 103         T.J. Oshie       RW  Mon, Jan 27        Back
# 104      Morgan Barron        C  Thu, Jan 30  Upper Body
# 105         Adam Lowry        C  Mon, Jan 27  Upper Body
#
#                                     Injury Status        Team
# 0                                      Day-to-Day     Anaheim
# 1    IR. Expected to be out until at least Sep 15     Anaheim
# 2    IR. Expected to be out until at least Feb 22      Boston
# 3                                      Day-to-Day     Buffalo
# 4                                      Day-to-Day     Buffalo
# ..                                            ...         ...
# 101  IR. Expected to be out until at least Feb 22  Washington
# 102   IR. Expected to be out until at least Jul 1  Washington
# 103  IR. Expected to be out until at least Sep 15  Washington
# 104  IR. Expected to be out until at least Feb 22    Winnipeg
# 105  IR. Expected to be out until at least Feb 22    Winnipeg
#
# [106 rows x 6 columns]

# %%
team_df = projections_df[projections_df["Team"] == 'Toronto Maple Leafs']
team_df
# Out:
#                     Team  Injured                Player Position  \
# 3    Toronto Maple Leafs    False       Auston Matthews        F
# 13   Toronto Maple Leafs    False          Bobby McMann        F
# 46   Toronto Maple Leafs    False      William Nylander        F
# 47   Toronto Maple Leafs    False          John Tavares        F
# 81   Toronto Maple Leafs    False         Matthew Knies        F
# 217  Toronto Maple Leafs    False              Max Domi        F
# 235  Toronto Maple Leafs    False        Max Pacioretty        F
# 247  Toronto Maple Leafs    False          Mitch Marner        F
# 344  Toronto Maple Leafs    False         Morgan Rielly        D
# 376  Toronto Maple Leafs    False           Jake McCabe        D
# 393  Toronto Maple Leafs    False  Oliver Ekman-Larsson        D
# 473  Toronto Maple Leafs    False        Steven Lorentz        F
# 494  Toronto Maple Leafs    False          Simon Benoit        D
# 534  Toronto Maple Leafs    False           David Kampf        F
# 535  Toronto Maple Leafs    False       Pontus Holmberg        F
# 553  Toronto Maple Leafs    False           Chris Tanev        D
# 561  Toronto Maple Leafs     True         Conor Timmins        D
# 577  Toronto Maple Leafs    False    Nicholas Robertson        F
# 596  Toronto Maple Leafs    False        Philippe Myers        D
# 640  Toronto Maple Leafs    False         Alex Nylander        F
# 642  Toronto Maple Leafs    False          Alex Steeves        F
# 672  Toronto Maple Leafs     True          Connor Dewar        F
# 697  Toronto Maple Leafs    False         Fraser Minten        F
# 709  Toronto Maple Leafs    False         Jani Hakanpää        D
# 765  Toronto Maple Leafs    False      Nikita Grebenkin        F
# 788  Toronto Maple Leafs    False           Ryan Reaves        F
#
#      games_this_week  proj_fantasy_pts
# 3                1.0          2.955752
# 13               1.0          2.672566
# 46               1.0          2.159292
# 47               1.0          2.398230
# 81               1.0          2.159292
# 217              1.0          1.619469
# 235              1.0          1.194690
# 247              1.0          1.911504
# 344              1.0          1.433628
# 376              1.0          0.823009
# 393              1.0          0.716814
# 473              1.0          0.000000
# 494              1.0          0.000000
# 534              1.0          0.000000
# 535              1.0          0.000000
# 553              1.0          0.008850
# 561              1.0          0.000000
# 577              1.0          0.000000
# 596              1.0          0.008850
# 640              1.0               NaN
# 642              1.0               NaN
# 672              1.0          0.000000
# 697              1.0               NaN
# 709              1.0               NaN
# 765              1.0               NaN
# 788              1.0               NaN

# %%
goalie_df
# Out:
#                      Team  Injured                 Player Position  \
# 0       Vancouver Canucks    False      Vancouver Canucks        G
# 1         St. Louis Blues    False        St. Louis Blues        G
# 2        New York Rangers    False       New York Rangers        G
# 3           Anaheim Ducks    False          Anaheim Ducks        G
# 4     Pittsburgh Penguins    False    Pittsburgh Penguins        G
# 5        Florida Panthers    False       Florida Panthers        G
# 6         San Jose Sharks    False        San Jose Sharks        G
# 7      Chicago Blackhawks    False     Chicago Blackhawks        G
# 8      New York Islanders    False     New York Islanders        G
# 9            Dallas Stars    False           Dallas Stars        G
# 10     Montreal Canadiens    False     Montreal Canadiens        G
# 11         Seattle Kraken    False         Seattle Kraken        G
# 12         Calgary Flames    False         Calgary Flames        G
# 13        Ottawa Senators    False        Ottawa Senators        G
# 14   Vegas Golden Knights    False   Vegas Golden Knights        G
# 15  Columbus Blue Jackets    False  Columbus Blue Jackets        G
# 16         Buffalo Sabres    False         Buffalo Sabres        G
# 17    Nashville Predators    False    Nashville Predators        G
# 18    Tampa Bay Lightning    False    Tampa Bay Lightning        G
# 19       Utah Hockey Club    False       Utah Hockey Club        G
# 20    Washington Capitals    False    Washington Capitals        G
# 21    Carolina Hurricanes    False    Carolina Hurricanes        G
# 22      Los Angeles Kings    False      Los Angeles Kings        G
# 23      Detroit Red Wings    False      Detroit Red Wings        G
# 24    Toronto Maple Leafs    False    Toronto Maple Leafs        G
# 25         Minnesota Wild    False         Minnesota Wild        G
# 26          Boston Bruins    False          Boston Bruins        G
# 27    Philadelphia Flyers    False    Philadelphia Flyers        G
# 28      New Jersey Devils    False      New Jersey Devils        G
#
#     games_this_week  proj_fantasy_pts
# 0                 1             2.620
# 1                 1             1.580
# 2                 1             2.280
# 3                 1             2.560
# 4                 1             1.992
# 5                 1             2.356
# 6                 1             2.692
# 7                 1             2.028
# 8                 1             2.572
# 9                 1             1.420
# 10                2             4.880
# 11                1             2.284
# 12                1             1.884
# 13                1             2.564
# 14                1             2.244
# 15                1             2.176
# 16                1             1.724
# 17                1             1.948
# 18                2             4.272
# 19                2             6.048
# 20                1             2.136
# 21                1             2.136
# 22                1             2.064
# 23                1             2.440
# 24                1             2.360
# 25                1             2.212
# 26                1             2.644
# 27                1             2.064
# 28                1             2.136

# %%
final_df
# Out:
#                     Team  Injured               Player Position  \
# 3    Toronto Maple Leafs    False      Auston Matthews        F
# 69      New York Rangers    False       Artemi Panarin        F
# 46   Toronto Maple Leafs    False     William Nylander        F
# 355  Pittsburgh Penguins    False        Erik Karlsson        D
# 155        Boston Bruins    False       David Pastrnak        F
# ..                   ...      ...                  ...      ...
# 854  Nashville Predators    False  Nashville Predators        G
# 849       Calgary Flames    False       Calgary Flames        G
# 853       Buffalo Sabres    False       Buffalo Sabres        G
# 838      St. Louis Blues    False      St. Louis Blues        G
# 846         Dallas Stars    False         Dallas Stars        G
#
#      games_this_week  proj_fantasy_pts      pv
# 3                1.0              2.96  13.250
# 69               1.0              2.26  11.643
# 46               1.0              2.16  11.500
# 355              1.0              1.62  11.500
# 155              1.0              1.64  11.250
# ..               ...               ...     ...
# 854              1.0              1.95   0.000
# 849              1.0              1.88   0.000
# 853              1.0              1.72   0.000
# 838              1.0              1.58   0.000
# 846              1.0              1.42   0.000
#
# [554 rows x 7 columns]
